# %%
#####################################################
##################### Imports #######################
#####################################################

import os
import time
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, average_precision_score, confusion_matrix, classification_report
)
from torchsummary import summary

#####################################################
##################### Metrics #######################
#####################################################

def compute_accuracy(outputs, labels, threshold=0.5):
    """Compute binary accuracy using sklearn.metrics.accuracy_score."""
    preds = (outputs >= threshold).cpu().numpy()
    true = labels.cpu().numpy()
    return accuracy_score(true, preds)

#####################################################
#################### Checkpoint #####################
#####################################################

def save_checkpoint(model, optimizer, history, epoch, path='checkpoint.pth'):
    """Save model, optimizer state and history."""
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'epoch': epoch,
        'history': history
    }
    torch.save(checkpoint, path)
    print(f"[Checkpoint] Saved at epoch {epoch+1} → {path}")

def load_checkpoint(model, optimizer, path="checkpoint.pth", device='cpu'):
    """Load model, optimizer state, epoch and history from checkpoint."""
    checkpoint = torch.load(path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    start_epoch = checkpoint['epoch'] + 1  # Continue from next epoch
    history = checkpoint['history']
    print(f"[Checkpoint] Loaded from '{path}', resuming at epoch {start_epoch}.")
    return model, optimizer, start_epoch, history

#####################################################
###################### Train ########################
#####################################################

def train_one_epoch(model, loader, criterion, optimizer, device, threshold=0.5):
    model.train()
    running_loss = 0.0
    running_corrects = 0
    total_samples = 0

    for images, labels in tqdm(loader, desc="Training", leave=False):
        images = images.to(device)
        labels = labels.float().unsqueeze(1).to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        batch_loss = loss.item() * labels.size(0)
        batch_acc = compute_accuracy(outputs, labels, threshold) * labels.size(0)

        running_loss += batch_loss
        running_corrects += batch_acc
        total_samples += labels.size(0)

    epoch_loss = running_loss / total_samples
    epoch_acc = running_corrects / total_samples

    return epoch_loss, epoch_acc

def evaluate_model(model, loader, criterion, device, threshold=0.5, desc="Evaluation"):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    total_samples = 0

    with torch.no_grad():
        for images, labels in tqdm(loader, desc=desc, leave=False):
            images = images.to(device)
            labels = labels.float().unsqueeze(1).to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            batch_loss = loss.item() * labels.size(0)
            batch_acc = compute_accuracy(outputs, labels, threshold) * labels.size(0)

            running_loss += batch_loss
            running_corrects += batch_acc
            total_samples += labels.size(0)

    epoch_loss = running_loss / total_samples
    epoch_acc = running_corrects / total_samples

    return epoch_loss, epoch_acc

def train_model(model, train_loader, val_loader, criterion, optimizer, device, epochs, start_epoch=0, history=None, 
                threshold=0.5, patience=5, checkpoint_path='checkpoint.pth', best_model_path='best_model.pth'):
    """Main training loop with checkpoint saving and early stopping."""

    if history is None:
        history = {
            'train_loss': [],
            'val_loss': [],
            'train_acc': [],
            'val_acc': [],
            'epoch_time': []
        }

    best_val_loss = np.inf
    patience_counter = 0

    model.to(device)

    for epoch in range(start_epoch, epochs):
        print(f"\nEpoch {epoch + 1}/{epochs}")

        start_time = time.time()

        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device, threshold)
        val_loss, val_acc = evaluate_model(model, val_loader, criterion, device, threshold, desc="Validation")

        epoch_time = time.time() - start_time

        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)
        history['epoch_time'].append(epoch_time)

        # Checkpoint Save
        save_checkpoint(model, optimizer, history, epoch, path=checkpoint_path)

        # Early Stopping Check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), best_model_path)
            print(f"[EarlyStopping] New best model saved (val_loss: {val_loss:.4f}) → {best_model_path}")
        else:
            patience_counter += 1
            print(f"[EarlyStopping] No improvement... ({patience_counter}/{patience} patience)")

        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, "
              f"Time: {epoch_time/60:.2f}min")

        # Stop if patience exceeded
        if patience_counter >= patience:
            print(f"[EarlyStopping] Stopping early at epoch {epoch+1}.")
            break

    return history

#####################################################
###################### Evaluate #####################
#####################################################

def evaluate_on_test(model, test_loader, device, threshold=0.5, class_names=['Other Fruits', 'Banana']):
    model.eval()
    all_outputs = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            all_outputs.extend(outputs.cpu().numpy().flatten())
            all_labels.extend(labels.cpu().numpy().flatten())

    all_outputs = np.array(all_outputs)
    all_labels = np.array(all_labels)

    preds = (all_outputs >= threshold).astype(np.float32)

    accuracy = accuracy_score(all_labels, preds)
    precision = precision_score(all_labels, preds, zero_division=0)
    recall = recall_score(all_labels, preds, zero_division=0)
    f1 = f1_score(all_labels, preds, zero_division=0)
    
    try:
        roc_auc = roc_auc_score(all_labels, all_outputs)
    except ValueError:
        roc_auc = None
    
    try:
        pr_auc = average_precision_score(all_labels, all_outputs)
    except ValueError:
        pr_auc = None

    print("\n Test Metrics:")
    print(f"Accuracy:   {accuracy:.4f}")
    print(f"Precision:  {precision:.4f}")
    print(f"Recall:     {recall:.4f}")
    print(f"F1 Score:   {f1:.4f}")
    if roc_auc is not None:
        print(f"ROC-AUC:    {roc_auc:.4f}")
    else:
        print("ROC-AUC:    Não calculável (só uma classe presente no teste).")
    if pr_auc is not None:
        print(f"PR-AUC:     {pr_auc:.4f}")
    else:
        print("PR-AUC:     Não calculável (só uma classe presente no teste).")

    print("\nClassification Report:")
    print(classification_report(all_labels, preds, digits=4))

    cm = confusion_matrix(all_labels, preds, normalize='pred')
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, cmap='Oranges', xticklabels=class_names, yticklabels=class_names,
                vmin=0, vmax=1)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix (Test Split)')
    plt.tight_layout()
    plt.show()

#####################################################
###################### Plots ########################
#####################################################

def plot_training_history(history):
    sns.set(style='whitegrid')

    epochs = range(1, len(history['train_loss']) + 1)

    plt.figure(figsize=(14, 5))

    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_loss'], 'b-', label='Training Loss')
    plt.plot(epochs, history['val_loss'], 'r-', label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss per Epoch')
    plt.legend()
    plt.grid(True)

    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_acc'], 'b-', label='Training Accuracy')
    plt.plot(epochs, history['val_acc'], 'r-', label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy per Epoch')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()
    sns.reset_defaults()
    
def show_random_test_predictions(model, test_loader, device, class_names=['Other Fruits', 'Banana'], threshold=0.5):
    model.eval()
    samples = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images)
            preds = (outputs.cpu().numpy().flatten() >= threshold).astype(int)

            for img, true, pred in zip(images.cpu(), labels.cpu().numpy(), preds):
                samples.append((img, true, pred))

    selected_samples = random.sample(samples, 12)

    plt.figure(figsize=(12, 9))
    for i, (img, true, pred) in enumerate(selected_samples):
        image = img.numpy().transpose(1, 2, 0)  # C,H,W → H,W,C
        image = (image * 0.5) + 0.5  # Un-normalizar de [-1,1] para [0,1]

        plt.subplot(3, 4, i + 1)
        plt.imshow(np.clip(image, 0, 1))
        true_class = class_names[true]
        pred_class = class_names[pred]
        color = 'green' if true_class == pred_class else 'red'
        plt.title(f"True: {true_class}\nPred: {pred_class}", color=color, fontsize=9)
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Resnet18

# %%
#####################################################
################## Data Preparation #################
#####################################################

# Image transformations
train_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1), shear=5),
    transforms.RandomResizedCrop(128),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

valid_test_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# Dataset paths
data_dir = "../../dataset_binary"
train_dir = os.path.join(data_dir, "train")
valid_dir = os.path.join(data_dir, "valid")
test_dir = os.path.join(data_dir, "test")

# Datasets and Dataloaders
BATCH_SIZE = 64
NUM_WORKERS = 20

train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
valid_dataset = datasets.ImageFolder(valid_dir, transform=valid_test_transform)
test_dataset = datasets.ImageFolder(test_dir, transform=valid_test_transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
val_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)

#####################################################
################ Transfer Learning ##################
#####################################################

# Load pretrained ResNet18
model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

# Freeze all layers
for param in model.parameters():
    param.requires_grad = False

# Replace fully connected layer for binary classification
num_ftrs = model.fc.in_features
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 1),
    nn.Sigmoid()
)

# Multi-GPU (DataParallel)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs!")
    model = nn.DataParallel(model)

model = model.to(device)

# Loss and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.module.fc.parameters(), lr=0.001)
# Out:
# /home/diogo23039/anaconda3/envs/image_processing/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using 3 GPUs!

# %%
#####################################################
################ Training and Evaluation ############
#####################################################

# Here reuse your previous training loop functions (train_model, evaluate_on_test, etc.)

history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    epochs=30,
    checkpoint_path='checkpoint_resnet18.pth',
    best_model_path='best_resnet18.pth'
)
# Out:
# Epoch 1/30
# [Checkpoint] Saved at epoch 1 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.2928) → best_resnet18.pth
# Train Loss: 0.5425, Train Acc: 0.7211, Val Loss: 0.2928, Val Acc: 0.8875, Time: 0.12min
#
# Epoch 2/30
# [Checkpoint] Saved at epoch 2 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.2127) → best_resnet18.pth
# Train Loss: 0.4540, Train Acc: 0.7887, Val Loss: 0.2127, Val Acc: 0.9125, Time: 0.12min
#
# Epoch 3/30
# [Checkpoint] Saved at epoch 3 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1867) → best_resnet18.pth
# Train Loss: 0.4336, Train Acc: 0.8018, Val Loss: 0.1867, Val Acc: 0.9375, Time: 0.12min
#
# Epoch 4/30
# [Checkpoint] Saved at epoch 4 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1841) → best_resnet18.pth
# Train Loss: 0.4121, Train Acc: 0.8098, Val Loss: 0.1841, Val Acc: 0.9250, Time: 0.12min
#
# Epoch 5/30
# [Checkpoint] Saved at epoch 5 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1826) → best_resnet18.pth
# Train Loss: 0.4365, Train Acc: 0.7966, Val Loss: 0.1826, Val Acc: 0.9125, Time: 0.12min
#
# Epoch 6/30
# [Checkpoint] Saved at epoch 6 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1604) → best_resnet18.pth
# Train Loss: 0.4062, Train Acc: 0.8095, Val Loss: 0.1604, Val Acc: 0.9625, Time: 0.11min
#
# Epoch 7/30
# [Checkpoint] Saved at epoch 7 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1535) → best_resnet18.pth
# Train Loss: 0.4080, Train Acc: 0.8162, Val Loss: 0.1535, Val Acc: 0.9500, Time: 0.11min
#
# Epoch 8/30
# [Checkpoint] Saved at epoch 8 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1508) → best_resnet18.pth
# Train Loss: 0.4125, Train Acc: 0.8041, Val Loss: 0.1508, Val Acc: 0.9500, Time: 0.12min
#
# Epoch 9/30
# [Checkpoint] Saved at epoch 9 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1403) → best_resnet18.pth
# Train Loss: 0.4060, Train Acc: 0.8134, Val Loss: 0.1403, Val Acc: 0.9750, Time: 0.12min
#
# Epoch 10/30
# [Checkpoint] Saved at epoch 10 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1357) → best_resnet18.pth
# Train Loss: 0.4040, Train Acc: 0.8142, Val Loss: 0.1357, Val Acc: 0.9750, Time: 0.11min
#
# Epoch 11/30
# [Checkpoint] Saved at epoch 11 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1355) → best_resnet18.pth
# Train Loss: 0.4067, Train Acc: 0.8139, Val Loss: 0.1355, Val Acc: 0.9500, Time: 0.11min
#
# Epoch 12/30
# [Checkpoint] Saved at epoch 12 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1315) → best_resnet18.pth
# Train Loss: 0.4010, Train Acc: 0.8165, Val Loss: 0.1315, Val Acc: 0.9875, Time: 0.12min
#
# Epoch 13/30
# [Checkpoint] Saved at epoch 13 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1296) → best_resnet18.pth
# Train Loss: 0.3949, Train Acc: 0.8147, Val Loss: 0.1296, Val Acc: 0.9750, Time: 0.12min
#
# Epoch 14/30
# [Checkpoint] Saved at epoch 14 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1279) → best_resnet18.pth
# Train Loss: 0.4003, Train Acc: 0.8168, Val Loss: 0.1279, Val Acc: 0.9750, Time: 0.12min
#
# Epoch 15/30
# [Checkpoint] Saved at epoch 15 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1192) → best_resnet18.pth
# Train Loss: 0.3895, Train Acc: 0.8214, Val Loss: 0.1192, Val Acc: 0.9750, Time: 0.12min
#
# Epoch 16/30
# [Checkpoint] Saved at epoch 16 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (1/5 patience)
# Train Loss: 0.4027, Train Acc: 0.8108, Val Loss: 0.1241, Val Acc: 0.9750, Time: 0.12min
#
# Epoch 17/30
# [Checkpoint] Saved at epoch 17 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (2/5 patience)
# Train Loss: 0.3933, Train Acc: 0.8139, Val Loss: 0.1228, Val Acc: 0.9750, Time: 0.12min
#
# Epoch 18/30
# [Checkpoint] Saved at epoch 18 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (3/5 patience)
# Train Loss: 0.3937, Train Acc: 0.8173, Val Loss: 0.1327, Val Acc: 0.9625, Time: 0.12min
#
# Epoch 19/30
# [Checkpoint] Saved at epoch 19 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (4/5 patience)
# Train Loss: 0.3979, Train Acc: 0.8180, Val Loss: 0.1247, Val Acc: 0.9750, Time: 0.12min
#
# Epoch 20/30
# [Checkpoint] Saved at epoch 20 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (5/5 patience)
# Train Loss: 0.3861, Train Acc: 0.8186, Val Loss: 0.1300, Val Acc: 0.9625, Time: 0.11min
# [EarlyStopping] Stopping early at epoch 20.

# %%
# Plot training history
plot_training_history(history)

# %%
# Final test evaluation
evaluate_on_test(model, test_loader, device, threshold=0.5, class_names=['Other Fruits', 'Banana'])
# Out:
#  Test Metrics:
# Accuracy:   0.8500
# Precision:  1.0000
# Recall:     0.7000
# F1 Score:   0.8235
# ROC-AUC:    0.9600
# PR-AUC:     0.9729
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7692    1.0000    0.8696        20
#            1     1.0000    0.7000    0.8235        20
#
#     accuracy                         0.8500        40
#    macro avg     0.8846    0.8500    0.8465        40
# weighted avg     0.8846    0.8500    0.8465        40

# %%
show_random_test_predictions(model, test_loader, device, class_names=train_dataset.classes, threshold=0.5)

# %% [markdown]
# # Resnet50

# %%
#####################################################
################## Data Preparation #################
#####################################################

# Image transformations
train_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1), shear=5),
    transforms.RandomResizedCrop(128),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

valid_test_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# Dataset paths
data_dir = "../../dataset_binary"
train_dir = os.path.join(data_dir, "train")
valid_dir = os.path.join(data_dir, "valid")
test_dir = os.path.join(data_dir, "test")

# Datasets and Dataloaders
BATCH_SIZE = 64
NUM_WORKERS = 20

train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
valid_dataset = datasets.ImageFolder(valid_dir, transform=valid_test_transform)
test_dataset = datasets.ImageFolder(test_dir, transform=valid_test_transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
val_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)

#####################################################
################ Transfer Learning ##################
#####################################################

# Load pretrained ResNet18
model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)

# Freeze all layers
for param in model.parameters():
    param.requires_grad = False

# Replace fully connected layer for binary classification
num_ftrs = model.fc.in_features
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 1),
    nn.Sigmoid()
)

# Multi-GPU (DataParallel)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs!")
    model = nn.DataParallel(model)

model = model.to(device)

# Loss and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.module.fc.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /home/diogo23039/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# Using 3 GPUs!

# %%
#####################################################
################ Training and Evaluation ############
#####################################################

# Here reuse your previous training loop functions (train_model, evaluate_on_test, etc.)

history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    epochs=30,
    checkpoint_path='checkpoint_resnet18.pth',
    best_model_path='best_resnet18.pth'
)
# Out:
# Epoch 1/30
# [Checkpoint] Saved at epoch 1 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.4094) → best_resnet18.pth
# Train Loss: 0.5894, Train Acc: 0.7219, Val Loss: 0.4094, Val Acc: 0.8750, Time: 0.15min
#
# Epoch 2/30
# [Checkpoint] Saved at epoch 2 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.3052) → best_resnet18.pth
# Train Loss: 0.4740, Train Acc: 0.8165, Val Loss: 0.3052, Val Acc: 0.9125, Time: 0.14min
#
# Epoch 3/30
# [Checkpoint] Saved at epoch 3 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.2481) → best_resnet18.pth
# Train Loss: 0.4204, Train Acc: 0.8289, Val Loss: 0.2481, Val Acc: 0.9375, Time: 0.14min
#
# Epoch 4/30
# [Checkpoint] Saved at epoch 4 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.2104) → best_resnet18.pth
# Train Loss: 0.4067, Train Acc: 0.8260, Val Loss: 0.2104, Val Acc: 0.9375, Time: 0.15min
#
# Epoch 5/30
# [Checkpoint] Saved at epoch 5 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1994) → best_resnet18.pth
# Train Loss: 0.3795, Train Acc: 0.8322, Val Loss: 0.1994, Val Acc: 0.9375, Time: 0.15min
#
# Epoch 6/30
# [Checkpoint] Saved at epoch 6 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1974) → best_resnet18.pth
# Train Loss: 0.3752, Train Acc: 0.8477, Val Loss: 0.1974, Val Acc: 0.9250, Time: 0.15min
#
# Epoch 7/30
# [Checkpoint] Saved at epoch 7 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1821) → best_resnet18.pth
# Train Loss: 0.3699, Train Acc: 0.8407, Val Loss: 0.1821, Val Acc: 0.9625, Time: 0.14min
#
# Epoch 8/30
# [Checkpoint] Saved at epoch 8 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1700) → best_resnet18.pth
# Train Loss: 0.3674, Train Acc: 0.8482, Val Loss: 0.1700, Val Acc: 0.9500, Time: 0.14min
#
# Epoch 9/30
# [Checkpoint] Saved at epoch 9 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (1/5 patience)
# Train Loss: 0.3613, Train Acc: 0.8508, Val Loss: 0.1713, Val Acc: 0.9500, Time: 0.14min
#
# Epoch 10/30
# [Checkpoint] Saved at epoch 10 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (2/5 patience)
# Train Loss: 0.3421, Train Acc: 0.8603, Val Loss: 0.1705, Val Acc: 0.9500, Time: 0.14min
#
# Epoch 11/30
# [Checkpoint] Saved at epoch 11 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1538) → best_resnet18.pth
# Train Loss: 0.3387, Train Acc: 0.8518, Val Loss: 0.1538, Val Acc: 0.9625, Time: 0.14min
#
# Epoch 12/30
# [Checkpoint] Saved at epoch 12 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1492) → best_resnet18.pth
# Train Loss: 0.3432, Train Acc: 0.8541, Val Loss: 0.1492, Val Acc: 0.9500, Time: 0.15min
#
# Epoch 13/30
# [Checkpoint] Saved at epoch 13 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (1/5 patience)
# Train Loss: 0.3317, Train Acc: 0.8644, Val Loss: 0.1623, Val Acc: 0.9625, Time: 0.15min
#
# Epoch 14/30
# [Checkpoint] Saved at epoch 14 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1357) → best_resnet18.pth
# Train Loss: 0.3297, Train Acc: 0.8647, Val Loss: 0.1357, Val Acc: 0.9625, Time: 0.15min
#
# Epoch 15/30
# [Checkpoint] Saved at epoch 15 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (1/5 patience)
# Train Loss: 0.3419, Train Acc: 0.8549, Val Loss: 0.1431, Val Acc: 0.9625, Time: 0.14min
#
# Epoch 16/30
# [Checkpoint] Saved at epoch 16 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (2/5 patience)
# Train Loss: 0.3400, Train Acc: 0.8567, Val Loss: 0.1420, Val Acc: 0.9625, Time: 0.14min
#
# Epoch 17/30
# [Checkpoint] Saved at epoch 17 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (3/5 patience)
# Train Loss: 0.3357, Train Acc: 0.8534, Val Loss: 0.1407, Val Acc: 0.9625, Time: 0.14min
#
# Epoch 18/30
# [Checkpoint] Saved at epoch 18 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1346) → best_resnet18.pth
# Train Loss: 0.3304, Train Acc: 0.8603, Val Loss: 0.1346, Val Acc: 0.9625, Time: 0.15min
#
# Epoch 19/30
# [Checkpoint] Saved at epoch 19 → checkpoint_resnet18.pth
# [EarlyStopping] New best model saved (val_loss: 0.1258) → best_resnet18.pth
# Train Loss: 0.3363, Train Acc: 0.8528, Val Loss: 0.1258, Val Acc: 0.9625, Time: 0.14min
#
# Epoch 20/30
# [Checkpoint] Saved at epoch 20 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (1/5 patience)
# Train Loss: 0.3270, Train Acc: 0.8577, Val Loss: 0.1296, Val Acc: 0.9625, Time: 0.14min
#
# Epoch 21/30
# [Checkpoint] Saved at epoch 21 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (2/5 patience)
# Train Loss: 0.3310, Train Acc: 0.8544, Val Loss: 0.1274, Val Acc: 0.9500, Time: 0.14min
#
# Epoch 22/30
# [Checkpoint] Saved at epoch 22 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (3/5 patience)
# Train Loss: 0.3314, Train Acc: 0.8559, Val Loss: 0.1294, Val Acc: 0.9500, Time: 0.14min
#
# Epoch 23/30
# [Checkpoint] Saved at epoch 23 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (4/5 patience)
# Train Loss: 0.3263, Train Acc: 0.8606, Val Loss: 0.1410, Val Acc: 0.9625, Time: 0.15min
#
# Epoch 24/30
# [Checkpoint] Saved at epoch 24 → checkpoint_resnet18.pth
# [EarlyStopping] No improvement... (5/5 patience)
# Train Loss: 0.3095, Train Acc: 0.8704, Val Loss: 0.1336, Val Acc: 0.9625, Time: 0.14min
# [EarlyStopping] Stopping early at epoch 24.

# %%
# Plot training history
plot_training_history(history)

# %%
# Final test evaluation
evaluate_on_test(model, test_loader, device, threshold=0.5, class_names=['Other Fruits', 'Banana'])
# Out:
#  Test Metrics:
# Accuracy:   0.9000
# Precision:  1.0000
# Recall:     0.8000
# F1 Score:   0.8889
# ROC-AUC:    0.9850
# PR-AUC:     0.9875
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8333    1.0000    0.9091        20
#            1     1.0000    0.8000    0.8889        20
#
#     accuracy                         0.9000        40
#    macro avg     0.9167    0.9000    0.8990        40
# weighted avg     0.9167    0.9000    0.8990        40

# %%
show_random_test_predictions(model, test_loader, device, class_names=train_dataset.classes, threshold=0.5)
